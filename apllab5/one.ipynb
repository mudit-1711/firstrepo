# %% [markdown]
# short circuit evaluation

# %%
if (input()) and (input()):
    print("yes")
else:
    print("no")
# Out:
# no

# %%
if (input()) or (input()):
    print("yes")
else:
    print("no")
# Out:
# no

# %% [markdown]
# exception handling

# %%
try :
    print(1/0)
except ZeroDivisionError:
    print("no")
# Out:
# no

# %% [markdown]
# functions with variable arguments

# %%
def a(*args):
    print(args)
    print(sum(args))

# %%
a(12,13,14)
# Out:
# (12, 13, 14)
# 39

# %%
def a(**kwargs):
    print(kwargs)

# %%
a(name="a",age=20,branch="IT")
# Out:
# {'name': 'a', 'age': 20, 'branch': 'IT'}
