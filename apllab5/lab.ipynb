# %%
l=[1,1,2,3,4,5,6,7]

# %%
l.append(8)
a=(1,2)
# Out:
# [1, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
l.remove(5)
# Out:
# [1, 1, 2, 3, 6, 7, 8]

# %%
target = 8
ok = False
for i in l :
    if i == target:
        print("found")
        ok = True
if not ok :
    print("NOt found")
# Out:
# found

# %%
target = 10
for i in l :
    if i == target:
        print("found")
else:
    print("NOt found")
# Out:
# NOt found

# %%
l.count(1)
# Out:
# 2

# %%
a=[2,3,1,8,7,4,5,65]

# %%
u=a+l
u
# Out:
# [2, 3, 1, 8, 7, 4, 5, 65, 1, 1, 2, 3, 5, 6, 7, 8]

# %%
a.sort()
a
# Out:
# [1, 2, 3, 4, 5, 7, 8, 65]

# %%
a.clear()

# %%
a
# Out:
# []

# %%
nums = [x for x in u if x%2==0]
nums
# Out:
# [2, 8, 4, 2, 6, 8]
